# %% [markdown]
# # Importando bibliotecas
#
# Neste arquivo, serão testados diferentes modelos estudados recentemente. Será feita a comparação de métodos do scikit learn e tensorflow

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Dados

# %%
dados = pd.read_excel('Hydrothermal1.xlsx')

estudo = pd.DataFrame(dados)

# %%
estudo = estudo.drop(estudo.columns[0], axis=1)
estudo
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                     14.05                      9.05
# 1                     25.95                      9.05
# 2                     14.05                     20.95
# 3                     25.95                     20.95
# 4                     14.05                      9.05
# 5                     25.95                      9.05
# 6                     14.05                     20.95
# 7                     25.95                     20.95
# 8                     10.00                     15.00
# 9                     30.00                     15.00
# 10                    20.00                      5.00
# 11                    20.00                     25.00
# 12                    20.00                     15.00
# 13                    20.00                     15.00
# 14                    20.00                     15.00
# 15                    20.00                     15.00
# 16                    20.00                     15.00
# 17                    20.00                     15.00
# 18                    20.00                     15.00
# 19                    20.00                     15.00
#
#     Tempo de pré-sacarificação  Eficiência de hidrólise (%)  \
# 0                         13.3                        58.87
# 1                         13.3                        75.94
# 2                         13.3                        53.28
# 3                         13.3                        58.19
# 4                         34.7                        82.00
# 5                         34.7                        91.61
# 6                         34.7                        61.08
# 7                         34.7                        70.81
# 8                         24.0                        51.70
# 9                         24.0                        74.56
# 10                        24.0                        79.78
# 11                        24.0                        57.19
# 12                         6.0                        58.83
# 13                        42.0                        78.80
# 14                        24.0                        73.53
# 15                        24.0                        72.51
# 16                        24.0                        76.40
# 17                        24.0                        76.55
# 18                        24.0                        75.06
# 19                        24.0                        77.55
#
#     Eficiência de fermentação (%)  Eficiência global em etanol (%)  \
# 0                           92.81                            54.64
# 1                           88.32                            67.07
# 2                           87.21                            46.47
# 3                           90.49                            52.66
# 4                           82.65                            67.78
# 5                           80.34                            73.60
# 6                           96.47                            58.92
# 7                           96.73                            68.50
# 8                           95.57                            49.41
# 9                           97.28                            72.53
# 10                          74.73                            59.62
# 11                          96.14                            54.98
# 12                          92.85                            54.62
# 13                          89.52                            70.55
# 14                          87.69                            64.48
# 15                          87.77                            63.64
# 16                          90.04                            68.79
# 17                          89.97                            68.88
# 18                          88.82                            66.67
# 19                          83.49                            64.75
#
#     Produtividade global em etanol (g/(L.h))
# 0                                       0.41
# 1                                       0.51
# 2                                       0.80
# 3                                       0.92
# 4                                       0.33
# 5                                       0.35
# 6                                       0.65
# 7                                       0.76
# 8                                       0.48
# 9                                       0.71
# 10                                      0.19
# 11                                      0.89
# 12                                      0.85
# 13                                      0.50
# 14                                      0.63
# 15                                      0.62
# 16                                      0.67
# 17                                      0.67
# 18                                      0.64
# 19                                      0.63

# %%
estudo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Concentração de enzimas                   20 non-null     float64
#  1   Concentração de biomassa                  20 non-null     float64
#  2   Tempo de pré-sacarificação                20 non-null     float64
#  3   Eficiência de hidrólise (%)               20 non-null     float64
#  4   Eficiência de fermentação (%)             20 non-null     float64
#  5   Eficiência global em etanol (%)           20 non-null     float64
#  6   Produtividade global em etanol (g/(L.h))  20 non-null     float64
# dtypes: float64(7)
# memory usage: 1.2 KB

# %%
estudo.describe()
# Out:
#        Concentração de enzimas  Concentração de biomassa  \
# count                20.000000                 20.000000
# mean                 20.000000                 15.000000
# std                   5.043078                  5.043078
# min                  10.000000                  5.000000
# 25%                  18.512500                 13.512500
# 50%                  20.000000                 15.000000
# 75%                  21.487500                 16.487500
# max                  30.000000                 25.000000
#
#        Tempo de pré-sacarificação  Eficiência de hidrólise (%)  \
# count                   20.000000                    20.000000
# mean                    24.000000                    70.212000
# std                      9.072573                    10.933717
# min                      6.000000                    51.700000
# 25%                     21.325000                    58.860000
# 50%                     24.000000                    74.045000
# 75%                     26.675000                    76.800000
# max                     42.000000                    91.610000
#
#        Eficiência de fermentação (%)  Eficiência global em etanol (%)  \
# count                      20.000000                        20.000000
# mean                       89.444500                        62.428000
# std                         5.913391                         7.973254
# min                        74.730000                        46.470000
# 25%                        87.570000                        54.895000
# 50%                        89.745000                        64.615000
# 75%                        93.530000                        68.572500
# max                        97.280000                        73.600000
#
#        Produtividade global em etanol (g/(L.h))
# count                                 20.000000
# mean                                   0.610500
# std                                    0.193676
# min                                    0.190000
# 25%                                    0.495000
# 50%                                    0.635000
# 75%                                    0.722500
# max                                    0.920000

# %%
sns.pairplot(estudo, diag_kind='kde')

# %% [markdown]
# # Random Forests

# %%
x = estudo[['Concentração de enzimas', 'Concentração de biomassa', 'Tempo de pré-sacarificação',
            #'Eficiência de hidrólise (%)','Eficiência de fermentação (%)','Eficiência global em etanol (%)'
            ]]
x
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                     14.05                      9.05
# 1                     25.95                      9.05
# 2                     14.05                     20.95
# 3                     25.95                     20.95
# 4                     14.05                      9.05
# 5                     25.95                      9.05
# 6                     14.05                     20.95
# 7                     25.95                     20.95
# 8                     10.00                     15.00
# 9                     30.00                     15.00
# 10                    20.00                      5.00
# 11                    20.00                     25.00
# 12                    20.00                     15.00
# 13                    20.00                     15.00
# 14                    20.00                     15.00
# 15                    20.00                     15.00
# 16                    20.00                     15.00
# 17                    20.00                     15.00
# 18                    20.00                     15.00
# 19                    20.00                     15.00
#
#     Tempo de pré-sacarificação
# 0                         13.3
# 1                         13.3
# 2                         13.3
# 3                         13.3
# 4                         34.7
# 5                         34.7
# 6                         34.7
# 7                         34.7
# 8                         24.0
# 9                         24.0
# 10                        24.0
# 11                        24.0
# 12                         6.0
# 13                        42.0
# 14                        24.0
# 15                        24.0
# 16                        24.0
# 17                        24.0
# 18                        24.0
# 19                        24.0

# %%
y = estudo[['Produtividade global em etanol (g/(L.h))']]
y
# Out:
#     Produtividade global em etanol (g/(L.h))
# 0                                       0.41
# 1                                       0.51
# 2                                       0.80
# 3                                       0.92
# 4                                       0.33
# 5                                       0.35
# 6                                       0.65
# 7                                       0.76
# 8                                       0.48
# 9                                       0.71
# 10                                      0.19
# 11                                      0.89
# 12                                      0.85
# 13                                      0.50
# 14                                      0.63
# 15                                      0.62
# 16                                      0.67
# 17                                      0.67
# 18                                      0.64
# 19                                      0.63

# %%
# Construindo o modelo

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %%
x_test
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 19                    20.00                     15.00
# 14                    20.00                     15.00
# 6                     14.05                     20.95
# 9                     30.00                     15.00
# 15                    20.00                     15.00
# 7                     25.95                     20.95
#
#     Tempo de pré-sacarificação
# 19                        24.0
# 14                        24.0
# 6                         34.7
# 9                         24.0
# 15                        24.0
# 7                         34.7

# %%
x_train
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 13                    20.00                     15.00
# 5                     25.95                      9.05
# 2                     14.05                     20.95
# 4                     14.05                      9.05
# 8                     10.00                     15.00
# 12                    20.00                     15.00
# 17                    20.00                     15.00
# 10                    20.00                      5.00
# 1                     25.95                      9.05
# 18                    20.00                     15.00
# 16                    20.00                     15.00
# 0                     14.05                      9.05
# 11                    20.00                     25.00
# 3                     25.95                     20.95
#
#     Tempo de pré-sacarificação
# 13                        42.0
# 5                         34.7
# 2                         13.3
# 4                         34.7
# 8                         24.0
# 12                         6.0
# 17                        24.0
# 10                        24.0
# 1                         13.3
# 18                        24.0
# 16                        24.0
# 0                         13.3
# 11                        24.0
# 3                         13.3

# %%
y_test
# Out:
#     Produtividade global em etanol (g/(L.h))
# 19                                      0.63
# 14                                      0.63
# 6                                       0.65
# 9                                       0.71
# 15                                      0.62
# 7                                       0.76

# %%
y_train
# Out:
#     Produtividade global em etanol (g/(L.h))
# 13                                      0.50
# 5                                       0.35
# 2                                       0.80
# 4                                       0.33
# 8                                       0.48
# 12                                      0.85
# 17                                      0.67
# 10                                      0.19
# 1                                       0.51
# 18                                      0.64
# 16                                      0.67
# 0                                       0.41
# 11                                      0.89
# 3                                       0.92

# %%
floresta = RandomForestRegressor(n_estimators=200)
floresta.fit(x_train,y_train)
# Out:
# C:\Users\audec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=200)

# %%
y_pred = floresta.predict(x_test)
y_pred
# Out:
# array([0.65416964, 0.65416964, 0.7056625 , 0.65069214, 0.65416964,
#        0.7565525 ])

# %%
mse = mean_squared_error(y_test, y_pred)
print("Erro Quadrático Médio:", mse)
# Out:
# Erro Quadrático Médio: 0.0014939214743409767

# %%
plt.scatter(y_test,y_test, label = 'real')
plt.scatter(y_pred,y_pred, label = 'previsto')

# plt.scatter(np.array(estudo['Eficiência global em etanol (%)']),y_pred , label = 'Previsto')
# plt.scatter(np.array(estudo['Eficiência global em etanol (%)']),y_test , label = 'Real')
# plt.xlabel('Eficiência global em etanol (%)')
# plt.ylabel('Produtividade global em etanol (g/(L.h))')
plt.legend()

# %%
importante = pd.DataFrame(floresta.feature_importances_,
                          index = ['CE', 'CB', 'Tps',
                                  #  'Eficiência de hidrólise (%)',
                                  #  'Eficiência de fermentação (%)',
                                  #  'Eficiência global em etanol (%)'
                                   ],
                          columns = ['Importância da feature']).sort_values('Importância da feature', ascending=True)

importante.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Redes neurais com tensorflow

# %%
train_dataset = x.sample(frac=0.8, random_state=0)
test_dataset = x.drop(train_dataset.index)

# %%
train_dataset
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 18                    20.00                     15.00
# 1                     25.95                      9.05
# 19                    20.00                     15.00
# 8                     10.00                     15.00
# 10                    20.00                      5.00
# 17                    20.00                     15.00
# 6                     14.05                     20.95
# 13                    20.00                     15.00
# 4                     14.05                      9.05
# 2                     14.05                     20.95
# 5                     25.95                      9.05
# 14                    20.00                     15.00
# 9                     30.00                     15.00
# 7                     25.95                     20.95
# 16                    20.00                     15.00
# 11                    20.00                     25.00
#
#     Tempo de pré-sacarificação
# 18                        24.0
# 1                         13.3
# 19                        24.0
# 8                         24.0
# 10                        24.0
# 17                        24.0
# 6                         34.7
# 13                        42.0
# 4                         34.7
# 2                         13.3
# 5                         34.7
# 14                        24.0
# 9                         24.0
# 7                         34.7
# 16                        24.0
# 11                        24.0

# %%
test_dataset
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                     14.05                      9.05
# 3                     25.95                     20.95
# 12                    20.00                     15.00
# 15                    20.00                     15.00
#
#     Tempo de pré-sacarificação
# 0                         13.3
# 3                         13.3
# 12                         6.0
# 15                        24.0

# %%
train_features
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 18                    20.00                     15.00
# 1                     25.95                      9.05
# 19                    20.00                     15.00
# 8                     10.00                     15.00
# 10                    20.00                      5.00
# 17                    20.00                     15.00
# 6                     14.05                     20.95
# 13                    20.00                     15.00
# 4                     14.05                      9.05
# 2                     14.05                     20.95
# 5                     25.95                      9.05
# 14                    20.00                     15.00
# 9                     30.00                     15.00
# 7                     25.95                     20.95
# 16                    20.00                     15.00
# 11                    20.00                     25.00
#
#     Tempo de pré-sacarificação
# 18                        24.0
# 1                         13.3
# 19                        24.0
# 8                         24.0
# 10                        24.0
# 17                        24.0
# 6                         34.7
# 13                        42.0
# 4                         34.7
# 2                         13.3
# 5                         34.7
# 14                        24.0
# 9                         24.0
# 7                         34.7
# 16                        24.0
# 11                        24.0

# %%
test_features
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                     14.05                      9.05
# 3                     25.95                     20.95
# 12                    20.00                     15.00
# 15                    20.00                     15.00
#
#     Tempo de pré-sacarificação
# 0                         13.3
# 3                         13.3
# 12                         6.0
# 15                        24.0

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
normalizer.adapt(np.array(train_features))

# %%
print(normalizer.mean.numpy())
# Out:
# [[20.     15.     26.4625]]

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[20. 15. 24.]]
#
# Normalized: [[ 0.    0.   -0.33]]

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Error [Produtividade global em etanol (g/(L.h))]')
  plt.legend()
  plt.grid(True)

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(20, activation='sigmoid'),
 #     layers.Dense(20, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_4 (Normalization) │ (16, 3)                │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7 (32.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 7 (32.00 B)

# %%
# %%time
history = dnn_model.fit(
    train_features,
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=200)
# Out:
# CPU times: total: 2.69 s
# Wall time: 16.1 s

# %%
plot_loss(history)

# %%
test_results = {}

test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)

pd.DataFrame(test_results, index=['Mean absolute error [Tps]']).T
# Out:
#            Mean absolute error [Tps]
# dnn_model                   0.053741

# %%
pred = dnn_model.predict(test_features)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000018F27B1AA20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
plt.scatter(test_labels,test_labels, label = 'real')
plt.scatter(pred,pred, label = 'previsto')

# plt.scatter(np.array(estudo['Eficiência global em etanol (%)']),y_pred , label = 'Previsto')
# plt.scatter(np.array(estudo['Eficiência global em etanol (%)']),y_test , label = 'Real')
# plt.xlabel('Eficiência global em etanol (%)')
# plt.ylabel('Produtividade global em etanol (g/(L.h))')
plt.legend()

# %% [markdown]
# # Novos testes

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_excel('Hydrothermal1.xlsx')
df = df.drop(df.columns[0], axis=1)  # Remove a primeira coluna

scaler = MinMaxScaler()
normalizado = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
normalizado
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                    0.2025                    0.2025
# 1                    0.7975                    0.2025
# 2                    0.2025                    0.7975
# 3                    0.7975                    0.7975
# 4                    0.2025                    0.2025
# 5                    0.7975                    0.2025
# 6                    0.2025                    0.7975
# 7                    0.7975                    0.7975
# 8                    0.0000                    0.5000
# 9                    1.0000                    0.5000
# 10                   0.5000                    0.0000
# 11                   0.5000                    1.0000
# 12                   0.5000                    0.5000
# 13                   0.5000                    0.5000
# 14                   0.5000                    0.5000
# 15                   0.5000                    0.5000
# 16                   0.5000                    0.5000
# 17                   0.5000                    0.5000
# 18                   0.5000                    0.5000
# 19                   0.5000                    0.5000
#
#     Tempo de pré-sacarificação  Eficiência de hidrólise (%)  \
# 0                     0.202778                     0.179654
# 1                     0.202778                     0.607367
# 2                     0.202778                     0.039589
# 3                     0.202778                     0.162616
# 4                     0.797222                     0.759208
# 5                     0.797222                     1.000000
# 6                     0.797222                     0.235029
# 7                     0.797222                     0.478827
# 8                     0.500000                     0.000000
# 9                     0.500000                     0.572789
# 10                    0.500000                     0.703583
# 11                    0.500000                     0.137560
# 12                    0.000000                     0.178652
# 13                    1.000000                     0.679028
# 14                    0.500000                     0.546981
# 15                    0.500000                     0.521423
# 16                    0.500000                     0.618893
# 17                    0.500000                     0.622651
# 18                    0.500000                     0.585317
# 19                    0.500000                     0.647707
#
#     Eficiência de fermentação (%)  Eficiência global em etanol (%)  \
# 0                        0.801774                         0.301143
# 1                        0.602661                         0.759307
# 2                        0.553437                         0.000000
# 3                        0.698891                         0.228161
# 4                        0.351220                         0.785477
# 5                        0.248780                         1.000000
# 6                        0.964080                         0.458902
# 7                        0.975610                         0.812016
# 8                        0.924169                         0.108367
# 9                        1.000000                         0.960560
# 10                       0.000000                         0.484703
# 11                       0.949446                         0.313675
# 12                       0.803548                         0.300405
# 13                       0.655876                         0.887578
# 14                       0.574723                         0.663841
# 15                       0.578271                         0.632879
# 16                       0.678936                         0.822705
# 17                       0.675831                         0.826023
# 18                       0.624834                         0.744563
# 19                       0.388470                         0.673793
#
#     Produtividade global em etanol (g/(L.h))
# 0                                   0.301370
# 1                                   0.438356
# 2                                   0.835616
# 3                                   1.000000
# 4                                   0.191781
# 5                                   0.219178
# 6                                   0.630137
# 7                                   0.780822
# 8                                   0.397260
# 9                                   0.712329
# 10                                  0.000000
# 11                                  0.958904
# 12                                  0.904110
# 13                                  0.424658
# 14                                  0.602740
# 15                                  0.589041
# 16                                  0.657534
# 17                                  0.657534
# 18                                  0.616438
# 19                                  0.602740

# %%
normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Concentração de enzimas                   20 non-null     float64
#  1   Concentração de biomassa                  20 non-null     float64
#  2   Tempo de pré-sacarificação                20 non-null     float64
#  3   Eficiência de hidrólise (%)               20 non-null     float64
#  4   Eficiência de fermentação (%)             20 non-null     float64
#  5   Eficiência global em etanol (%)           20 non-null     float64
#  6   Produtividade global em etanol (g/(L.h))  20 non-null     float64
# dtypes: float64(7)
# memory usage: 1.2 KB

# %%
normalizado
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                    0.2025                    0.2025
# 1                    0.7975                    0.2025
# 2                    0.2025                    0.7975
# 3                    0.7975                    0.7975
# 4                    0.2025                    0.2025
# 5                    0.7975                    0.2025
# 6                    0.2025                    0.7975
# 7                    0.7975                    0.7975
# 8                    0.0000                    0.5000
# 9                    1.0000                    0.5000
# 10                   0.5000                    0.0000
# 11                   0.5000                    1.0000
# 12                   0.5000                    0.5000
# 13                   0.5000                    0.5000
# 14                   0.5000                    0.5000
# 15                   0.5000                    0.5000
# 16                   0.5000                    0.5000
# 17                   0.5000                    0.5000
# 18                   0.5000                    0.5000
# 19                   0.5000                    0.5000
#
#     Tempo de pré-sacarificação  Eficiência de hidrólise (%)  \
# 0                     0.202778                     0.179654
# 1                     0.202778                     0.607367
# 2                     0.202778                     0.039589
# 3                     0.202778                     0.162616
# 4                     0.797222                     0.759208
# 5                     0.797222                     1.000000
# 6                     0.797222                     0.235029
# 7                     0.797222                     0.478827
# 8                     0.500000                     0.000000
# 9                     0.500000                     0.572789
# 10                    0.500000                     0.703583
# 11                    0.500000                     0.137560
# 12                    0.000000                     0.178652
# 13                    1.000000                     0.679028
# 14                    0.500000                     0.546981
# 15                    0.500000                     0.521423
# 16                    0.500000                     0.618893
# 17                    0.500000                     0.622651
# 18                    0.500000                     0.585317
# 19                    0.500000                     0.647707
#
#     Eficiência de fermentação (%)  Eficiência global em etanol (%)  \
# 0                        0.801774                         0.301143
# 1                        0.602661                         0.759307
# 2                        0.553437                         0.000000
# 3                        0.698891                         0.228161
# 4                        0.351220                         0.785477
# 5                        0.248780                         1.000000
# 6                        0.964080                         0.458902
# 7                        0.975610                         0.812016
# 8                        0.924169                         0.108367
# 9                        1.000000                         0.960560
# 10                       0.000000                         0.484703
# 11                       0.949446                         0.313675
# 12                       0.803548                         0.300405
# 13                       0.655876                         0.887578
# 14                       0.574723                         0.663841
# 15                       0.578271                         0.632879
# 16                       0.678936                         0.822705
# 17                       0.675831                         0.826023
# 18                       0.624834                         0.744563
# 19                       0.388470                         0.673793
#
#     Produtividade global em etanol (g/(L.h))
# 0                                   0.301370
# 1                                   0.438356
# 2                                   0.835616
# 3                                   1.000000
# 4                                   0.191781
# 5                                   0.219178
# 6                                   0.630137
# 7                                   0.780822
# 8                                   0.397260
# 9                                   0.712329
# 10                                  0.000000
# 11                                  0.958904
# 12                                  0.904110
# 13                                  0.424658
# 14                                  0.602740
# 15                                  0.589041
# 16                                  0.657534
# 17                                  0.657534
# 18                                  0.616438
# 19                                  0.602740

# %%
normalizado1 = normalizado[['Concentração de enzimas','Concentração de biomassa','Tempo de pré-sacarificação','Produtividade global em etanol (g/(L.h))']]
normalizado1
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                    0.2025                    0.2025
# 1                    0.7975                    0.2025
# 2                    0.2025                    0.7975
# 3                    0.7975                    0.7975
# 4                    0.2025                    0.2025
# 5                    0.7975                    0.2025
# 6                    0.2025                    0.7975
# 7                    0.7975                    0.7975
# 8                    0.0000                    0.5000
# 9                    1.0000                    0.5000
# 10                   0.5000                    0.0000
# 11                   0.5000                    1.0000
# 12                   0.5000                    0.5000
# 13                   0.5000                    0.5000
# 14                   0.5000                    0.5000
# 15                   0.5000                    0.5000
# 16                   0.5000                    0.5000
# 17                   0.5000                    0.5000
# 18                   0.5000                    0.5000
# 19                   0.5000                    0.5000
#
#     Tempo de pré-sacarificação  Produtividade global em etanol (g/(L.h))
# 0                     0.202778                                  0.301370
# 1                     0.202778                                  0.438356
# 2                     0.202778                                  0.835616
# 3                     0.202778                                  1.000000
# 4                     0.797222                                  0.191781
# 5                     0.797222                                  0.219178
# 6                     0.797222                                  0.630137
# 7                     0.797222                                  0.780822
# 8                     0.500000                                  0.397260
# 9                     0.500000                                  0.712329
# 10                    0.500000                                  0.000000
# 11                    0.500000                                  0.958904
# 12                    0.000000                                  0.904110
# 13                    1.000000                                  0.424658
# 14                    0.500000                                  0.602740
# 15                    0.500000                                  0.589041
# 16                    0.500000                                  0.657534
# 17                    0.500000                                  0.657534
# 18                    0.500000                                  0.616438
# 19                    0.500000                                  0.602740

# %%
ent_x=normalizado1[['Concentração de enzimas','Concentração de biomassa','Tempo de pré-sacarificação']]
ent_x
# Out:
#     Concentração de enzimas  Concentração de biomassa  \
# 0                    0.2025                    0.2025
# 1                    0.7975                    0.2025
# 2                    0.2025                    0.7975
# 3                    0.7975                    0.7975
# 4                    0.2025                    0.2025
# 5                    0.7975                    0.2025
# 6                    0.2025                    0.7975
# 7                    0.7975                    0.7975
# 8                    0.0000                    0.5000
# 9                    1.0000                    0.5000
# 10                   0.5000                    0.0000
# 11                   0.5000                    1.0000
# 12                   0.5000                    0.5000
# 13                   0.5000                    0.5000
# 14                   0.5000                    0.5000
# 15                   0.5000                    0.5000
# 16                   0.5000                    0.5000
# 17                   0.5000                    0.5000
# 18                   0.5000                    0.5000
# 19                   0.5000                    0.5000
#
#     Tempo de pré-sacarificação
# 0                     0.202778
# 1                     0.202778
# 2                     0.202778
# 3                     0.202778
# 4                     0.797222
# 5                     0.797222
# 6                     0.797222
# 7                     0.797222
# 8                     0.500000
# 9                     0.500000
# 10                    0.500000
# 11                    0.500000
# 12                    0.000000
# 13                    1.000000
# 14                    0.500000
# 15                    0.500000
# 16                    0.500000
# 17                    0.500000
# 18                    0.500000
# 19                    0.500000

# %%
import numpy as np
xizes = np.array(ent_x)
xizes
# Out:
# array([[0.2025    , 0.2025    , 0.20277778],
#        [0.7975    , 0.2025    , 0.20277778],
#        [0.2025    , 0.7975    , 0.20277778],
#        [0.7975    , 0.7975    , 0.20277778],
#        [0.2025    , 0.2025    , 0.79722222],
#        [0.7975    , 0.2025    , 0.79722222],
#        [0.2025    , 0.7975    , 0.79722222],
#        [0.7975    , 0.7975    , 0.79722222],
#        [0.        , 0.5       , 0.5       ],
#        [1.        , 0.5       , 0.5       ],
#        [0.5       , 0.        , 0.5       ],
#        [0.5       , 1.        , 0.5       ],
#        [0.5       , 0.5       , 0.        ],
#        [0.5       , 0.5       , 1.        ],
#        [0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       ],
#        [0.5       , 0.5       , 0.5       ]])

# %%
# Para cada linha na matriz de coeficientes
for linha in xizes:
    # Extrai os valores de x1, x2 e x3 da linha
    x1, x2, x3 = linha[0], linha[1], linha[2]

    # Calcula o valor de P_etOH usando a equação fornecida
    P_etOH = 0.65 + 0.05 * x1 - 0.02 * x1**2 + 0.20 * x2 - 0.04 * x2**2 - 0.08 * x3

    # Imprime o resultado para esta linha
    print("P_etOH:", P_etOH)
# Out:
# P_etOH: 0.6819424027777778
# P_etOH: 0.6997924027777778
# P_etOH: 0.7771424027777778
# P_etOH: 0.7949924027777777
# P_etOH: 0.6343868472222223
# P_etOH: 0.6522368472222222
# P_etOH: 0.7295868472222222
# P_etOH: 0.7474368472222221
# P_etOH: 0.7
# P_etOH: 0.73
# P_etOH: 0.63
# P_etOH: 0.79
# P_etOH: 0.76
# P_etOH: 0.68
# P_etOH: 0.72
# P_etOH: 0.72
# P_etOH: 0.72
# P_etOH: 0.72
# P_etOH: 0.72
# P_etOH: 0.72

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Error [Produtividade global em etanol (g/(L.h))]')
  plt.legend()
  plt.grid(True)

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(3, activation='sigmoid'),
 #     layers.Dense(20, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_4 (Normalization) │ (None, 3)              │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7 (32.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 7 (32.00 B)
