# %%
import pandas as pd

# %%
df = pd.read_csv('Experimental Data.csv')
df.describe()
# Out:
#           Cellulose   Hemicellulose        Lignin   Solids Loading [g/L]  \
# count  7.000000e+01    7.000000e+01  7.000000e+01              70.000000
# mean   6.600000e-01    8.300000e-02  2.520000e-01             157.857143
# std    3.354718e-16    1.397799e-17  1.118239e-16              18.328157
# min    6.600000e-01    8.300000e-02  2.520000e-01             150.000000
# 25%    6.600000e-01    8.300000e-02  2.520000e-01             150.000000
# 50%    6.600000e-01    8.300000e-02  2.520000e-01             150.000000
# 75%    6.600000e-01    8.300000e-02  2.520000e-01             150.000000
# max    6.600000e-01    8.300000e-02  2.520000e-01             200.000000
#
#         Enzyme Loading [g/L]   Time [h]   Glucose Concentration [g/L]  \
# count              70.000000  70.000000                     70.000000
# mean                0.365171  21.942857                     34.448586
# std                 0.282183  27.154889                     23.640194
# ...

# %%
df_synthetic = pd.read_csv('synthetic_hydrolysis_data_LHS.csv')
df_synthetic.describe()
# Out:
#          Cellulose   Hemicellulose       Lignin   Solids Loading [g/L]  \
# count  1100.000000     1100.000000  1100.000000            1100.000000
# mean      0.615380        0.116030     0.268620             149.161370
# std       0.024832        0.025127     0.024222              55.641246
# min       0.554000        0.058000     0.208000              55.737000
# 25%       0.601750        0.099250     0.251500              99.630750
# 50%       0.619000        0.118500     0.274500             154.916000
# 75%       0.636000        0.138000     0.289250             196.839750
# max       0.649000        0.150000     0.299000             247.855000
#
#         Enzyme Loading [g/L]     Time [h]   Glucose Concentration [g/L]  \
# count            1100.000000  1100.000000                   1100.000000
# mean                0.658090    24.818182                     30.267747
# std                 0.322175    31.304133                     24.163087
# ...
